# %% [markdown]
# ![2.1.jpg](attachment:2.1.jpg)

# %% [markdown]
# # 1、python速度慢的两大原因：
# ![2.2.jpg](attachment:2.2.jpg)

# %% [markdown]
# # 2、GIL是什么：
#
# ![2.3.jpg](attachment:2.3.jpg)

# %% [markdown]
# # 3、为什么有GIL这个东西？
#  ![2.4.jpg](attachment:2.4.jpg)

# %% [markdown]
# # 4、怎样规避GIL带来的限制？

# %% [markdown]
# ![2.5.jpg](attachment:2.5.jpg)
