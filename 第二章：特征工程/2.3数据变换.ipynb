# %% [markdown]
# # 数据变换
# 数据处理分为下面5大块：
# ![image.png](attachment:image.png)

# %% [markdown]
# # 归一化方法：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 图片数据变换
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 视频数据变换
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 文本数据变换
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 总结
#
# ![image.png](attachment:image.png)
