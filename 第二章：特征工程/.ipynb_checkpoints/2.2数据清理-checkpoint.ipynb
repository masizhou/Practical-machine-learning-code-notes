# %% [markdown]
# # 数据处理思维导图
# - 我们说数据是至关重要的，在第一章中介绍了如何获取数据，接下来我们看看有了数据之后如何清理
#
# ![1636882662.jpg](attachment:1636882662.jpg)

# %% [markdown]
# # 数据错误
# 错误的数据必须处理，不然影响后续工作:
# 比如你使用了错误的数据训练了模型，效果很好。然后部署到线上，线上就会预测新的数据，把这些数据给用户，用户就会反馈和训练数据完全不一样的数据，这么恶性循环，导致模型效果会越来越差。
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 数据错误的类型：
#
# 1、某一个数据不在正常的数据分布空间里面；
#
# 2、数据类型、必须唯一等等；
#
# 3、语义、语法、格式等错误。
#
# ![image.png](attachment:image.png)
