# %% [markdown]
# # 决策树做分类和回归：
# 如下图所示：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 决策树的优缺点：
# 优点：
# - （1）可解释性
# - （2）可以处理数值类和类别类的特征
#
# 缺点：
# - （1）不稳定，数据有噪音，可能构造的整个树就不一样了
# - （2）数据量很大，构造的树很复杂，会过拟合（剪枝操作可减轻）
# - （3）难以并行计算
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 随机森林：
#
# 前面说了决策树是不稳定的，即数据中有噪音，那么构造的树可能完全就不一样了，因此我们可以用多个树进行决策，这样就可以提高稳定性了，这个就是我们要说的随机森林。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # GBDT：
# 随机森林是使用并行的弱分类器，而GBDT是串行弱分类器的加法模型：
# ![image.png](attachment:image.png)

# %% [markdown]
# # 总结
#
# ![image.png](attachment:image.png)
